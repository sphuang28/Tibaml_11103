# %% [markdown]
# <a href="https://colab.research.google.com/github/sphuang28/Tibaml_11103/blob/main/10_12_OpenCV%E5%BD%B1%E5%83%8F%E6%95%B8%E6%93%9A%E8%99%95%E7%90%86%E8%88%87%E8%BE%A8%E8%AD%98_%E4%B8%8B%E5%8D%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
from PIL import ImageFont,ImageDraw, Image
import time

p1=cv2.VideoWriter(
    "1.mp4", 
    cv2.VideoWriter_fourcc(*'MP4V'), 
    300, 
    (500,300))
for x in range(20,500,1):
  dp.clear_output(True)
  m1=np.full((300, 500, 3), (230,230,255), np.uint8)#彩色
  m1=Image.fromarray(m1)
  ImageDraw.Draw(m1).text(
        (x,20),
        "測試123", 
        (0,255,0), 
        ImageFont.truetype("kaiu.ttf",50)
        )

  m1=np.array(m1)
  p1.write(m1)

  # cv2_imshow(m1)
  # time.sleep(0.5)
p1.release()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-81ae47c6c49e> in <module>
#      19         "測試123",
#      20         (0,255,0),
# ---> 21         ImageFont.truetype("kaiu.ttf",50)
#      22         )
#      23
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     646
#     647     try:
# --> 648         return freetype(font)
#     649     except OSError:
#     650         if not isPath(font):
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageFont.py in freetype(font)
#     643
#     644     def freetype(font):
# --> 645         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     646
#     647     try:
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     192                     return
#     193             self.font = core.getfont(
# --> 194                 font, size, index, encoding, layout_engine=layout_engine
#     195             )
#     196         else:
#
# OSError: cannot open resource

# %%
# !ffmpeg -i 1.mp4 -vcodec libx264 2.mp4

# %%
from os import XATTR_REPLACE
import base64
import codecs
import IPython.display as dp
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from PIL import ImageFont,ImageDraw, Image
import time

with codecs.open("2.mp4","rb") as f:
  d=base64.b64encode(f.read()).decode()

dp.HTML(
  f'<video src="data:video/mp4;base64,{d}"controls/>'
)
# Out:
# <video src="data:video/mp4;base64,..."controls/>

# %%
import base64
import codecs
import IPython.display as dp
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from PIL import ImageFont,ImageDraw, Image
import time

p1=cv2.VideoCapture("1.mp4")
while p1.isOpened()==True:
  ret,m1=p1.read()
  if ret==True:
    cv2_imshow(m1)
  else:
    break

# %%
import base64
import codecs
import IPython.display as dp
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from PIL import ImageFont,ImageDraw, Image
import time

p1=cv2.VideoCapture("1.mp4")
print("寬:",p1.get(3))
print("高:",p1.get(4))
print("FPS:",p1.get(5))
print("總影格數:",p1.get(7))
p1.set(1,200)#快轉用
while p1.isOpened()==True:
  ret,m1=p1.read()
  print("當前影格數:",p1.get(1))
  if ret==True:
    cv2_imshow(m1)
    #pass
  else:
    break
